# %%
from sklearn.model_selection import KFold
from tqdm.auto import tqdm
from sklearn.utils import shuffle
import torch
from torch import nn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import numpy as np
import pandas as pd

data = pd.read_excel(r"/kaggle/input/new-data-ji-ou/ji ou  big126 .xlsx",engine="openpyxl")
X = data.iloc[:, :5].values
y0 = data.iloc[:, -1].values
y = data.iloc[:, -1].values

test_losses = []
temp = 100000.0
temp= torch.tensor(temp, dtype=torch.float32)
test_losses.append(temp)
print(torch.sqrt(sum(test_losses)))
# Out:
# tensor(316.2278)

# %%
input_size = X[0].shape[0]
output_size = 1
learning_rate = 1e-2
num_epochs = 100
jiaocha_numbers = 10
save_rate = 0.95
hid_feature = 32
alpha,beta = 0.5,0.5
num_while=0
#alpha+beta = 1 !!!

num1=8
num2=16

# %%
def KlLoss(mu,logvar):
    return -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

class MLP(nn.Module):
    def __init__(self, input_size,hid_feature):
        super().__init__()
        self.input_size = input_size
        self.hid_feature = hid_feature

        self.encoder = nn.Sequential(
            nn.Linear(input_size,num1),
            nn.ELU(),
            nn.BatchNorm1d(num1),
            nn.Linear(num1,num2),
            nn.ELU(),
            nn.Linear(num2,hid_feature),
        )
        
        self.decoder = nn.Sequential(
            nn.Linear(hid_feature,num2),
            nn.ReLU(),
            nn.BatchNorm1d(num2),
            nn.Linear(num2,num1),
            nn.ELU(),
            nn.Linear(num1,input_size),
        )
        
        self.predicter = nn.Sequential(
            nn.Linear(hid_feature,num2),
            nn.ReLU(),
            nn.BatchNorm1d(num2),
            nn.Linear(num2,num1),
            nn.ELU(),
            nn.BatchNorm1d(num1),
            nn.Linear(num1,1),
        )
    
    def reparameterize(self,hid):
        mu,logvar = hid[:,hid_feature//2:],hid[:,:hid_feature//2]
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        z = mu + eps*std
        return mu,logvar,z

    def forward(self, x):
        hid = self.encoder(x)
        out = self.decoder(hid)
        y = self.predicter(hid)
        return out,y

# %%
while (torch.sqrt(sum(test_losses)/len(y)) > 0.32):
    num_while +=1
    test_losses = []
    
    def KlLoss(mu,logvar):
        return -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

    class MLP(nn.Module):
        def __init__(self, input_size,hid_feature):
            super().__init__()
            self.input_size = input_size
            self.hid_feature = hid_feature

            self.encoder = nn.Sequential(
                nn.Linear(input_size,num1),
                nn.ELU(),
                nn.BatchNorm1d(num1),
                nn.Linear(num1,num2),
                nn.ELU(),
                nn.Linear(num2,hid_feature),
            )

            self.decoder = nn.Sequential(
                nn.Linear(hid_feature,num2),
                nn.ReLU(),
                nn.BatchNorm1d(num2),
                nn.Linear(num2,num1),
                nn.ELU(),
                nn.Linear(num1,input_size),
            )

            self.predicter = nn.Sequential(
                nn.Linear(hid_feature,num2),
                nn.ReLU(),
                nn.BatchNorm1d(num2),
                nn.Linear(num2,num1),
                nn.ELU(),
                nn.BatchNorm1d(num1),
                nn.Linear(num1,1),
            )

        def reparameterize(self,hid):
            mu,logvar = hid[:,hid_feature//2:],hid[:,:hid_feature//2]
            std = torch.exp(0.5*logvar)
            eps = torch.randn_like(std)
            z = mu + eps*std
            return mu,logvar,z

        def forward(self, x):
            hid = self.encoder(x)
            out = self.decoder(hid)
            y = self.predicter(hid)
            return out,y

    
    kf = KFold(n_splits=jiaocha_numbers ,shuffle=True)
    results_df = pd.DataFrame()
    for fold, (train_index, test_index) in enumerate(kf.split(X)):
        model = MLP(input_size,hid_feature)
        criterion = nn.MSELoss()
        optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate,weight_decay=0.1)
        lr_scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer,lambda x: 1 - x/num_epochs,last_epoch=-1)
        
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y0[train_index], y0[test_index]
        scaler = MinMaxScaler()
        
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
        y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
        X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
        y_test_tensor = torch.tensor(y_test, dtype=torch.float32)
        
        train_data = torch.utils.data.TensorDataset(X_train_tensor, y_train_tensor)
        batch_size = X_train.shape[0]
        train_loader = torch.utils.data.DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
        
        losses = []
        
#        bar = tqdm(range(num_epochs))
#        bar.set_description("[ Training ]")
        bar = range(num_epochs)
        best = 100
        for idx,epoch in enumerate(bar):
            for i, (inputs, labels) in enumerate(train_loader):
                labels = labels 
                optimizer.zero_grad()
                out,y = model(inputs)
                label_loss = criterion(y, labels.unsqueeze(1))
                recon_loss = criterion(out, inputs)
                loss = alpha*recon_loss + beta*label_loss
                if  idx>num_epochs*save_rate and loss.item()<best:
                    best = loss.item()
                    torch.save(model.state_dict(), f'./model_fold_{fold + 1}.ckpt')
#                    print(f"loss:{loss.item()} saving...")
                loss.backward()
                optimizer.step()

            losses.append(loss.item())
            lr_scheduler.step()
#            if (epoch+1) % 100 == 0 :
#                print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.10f}')
#            bar.set_postfix({ 'Loss': f'{loss.item():.10f}','lr':f"{lr_scheduler.get_lr()[0]:.6f}"})

        model.load_state_dict(torch.load(f'./model_fold_{fold + 1}.ckpt'))
        model.eval()
        
        with torch.no_grad():
            _,test_outputs = model(X_test_tensor)
            y_pred = test_outputs.to('cpu')
            test_loss = criterion(test_outputs, y_test_tensor.unsqueeze(1))
            rmse = torch.sqrt(test_loss)  # 计算均方根误差
            y_out = (y_pred - y_test_tensor.numpy().reshape(len(y_test_tensor),1))/y_test_tensor.numpy().reshape(len(y_test_tensor),1)
            y_out = y_out.abs() < 0.1
            accuracy = y_out.sum()/len(y_out)
#            print(f'Test Loss: {test_loss:.10f}, Test RMSE: {rmse:.10f},Accuracy: {accuracy:.10f}')
            
        X_test = scaler.inverse_transform(X_test)
        fold_df = pd.DataFrame(X_test, columns = [str(i) for i in range(1, X[0].shape[0]+1)])
        fold_df['Test Labels'] = y_test
        fold_df['Test Outputs'] = y_pred.numpy()
        fold_df['Fold'] = fold + 1
        results_df = pd.concat([results_df, fold_df], ignore_index=True)
        test_losses.append(test_loss*len(y_test))
        
    print(f'The {num_while} times of test: The RMSE of this test:{torch.sqrt(sum(test_losses)/len(y)):.10f} and Linear_size1 = {num1} and Linear_size2 = {num2}')

    
    num2-=1
    if num2 == 11:
        num2 = 20
    if num2 == 20:
        num1 -=1
    if num1 == 5:
        num1 = 10
    
results_df.to_excel('test_data_and_outputs.xlsx', index=False)
print(f'Times of test:{num_while} and Linear_size1 = {num1} and Linear_size2 = {num2}')
# Out:
# The 1 times of test: The RMSE of this test:0.4289597571 and Linear_size1 = 8 and Linear_size2 = 16
# The 2 times of test: The RMSE of this test:0.5101928711 and Linear_size1 = 8 and Linear_size2 = 15
# The 3 times of test: The RMSE of this test:0.4134084880 and Linear_size1 = 8 and Linear_size2 = 14
# The 4 times of test: The RMSE of this test:0.4982110858 and Linear_size1 = 8 and Linear_size2 = 13
# The 5 times of test: The RMSE of this test:0.5408782959 and Linear_size1 = 8 and Linear_size2 = 12
# The 6 times of test: The RMSE of this test:0.4933682680 and Linear_size1 = 7 and Linear_size2 = 20
# The 7 times of test: The RMSE of this test:0.4372816682 and Linear_size1 = 7 and Linear_size2 = 19
# The 8 times of test: The RMSE of this test:0.4336703718 and Linear_size1 = 7 and Linear_size2 = 18
# The 9 times of test: The RMSE of this test:0.6164389253 and Linear_size1 = 7 and Linear_size2 = 17
# The 10 times of test: The RMSE of this test:0.4301291406 and Linear_size1 = 7 and Linear_size2 = 16
# The 11 times of test: The RMSE of this test:0.4301661551 and Linear_size1 = 7 and Linear_size2 = 15
# The 12 times of test: The RMSE of this test:0.4391157627 and Linear_size1 = 7 and Linear_size2 = 14
# The 13 times of test: The RMSE of this test:0.4492374063 and Linear_size1 = 7 and Linear_size2 = 13
# The 14 times of test: The RMSE of this test:0.4734620750 and Linear_size1 = 7 and Linear_size2 = 12
# The 15 times of test: The RMSE of this test:0.4789136648 and Linear_size1 = 6 and Linear_size2 = 20
# The 16 times of test: The RMSE of this test:0.4974941313 and Linear_size1 = 6 and Linear_size2 = 19
# The 17 times of test: The RMSE of this test:0.4183510542 and Linear_size1 = 6 and Linear_size2 = 18
# The 18 times of test: The RMSE of this test:0.4639051855 and Linear_size1 = 6 and Linear_size2 = 17
# The 19 times of test: The RMSE of this test:0.4758096933 and Linear_size1 = 6 and Linear_size2 = 16
# The 20 times of test: The RMSE of this test:0.4486297369 and Linear_size1 = 6 and Linear_size2 = 15
# The 21 times of test: The RMSE of this test:0.4112800956 and Linear_size1 = 6 and Linear_size2 = 14
# The 22 times of test: The RMSE of this test:0.5676588416 and Linear_size1 = 6 and Linear_size2 = 13
# The 23 times of test: The RMSE of this test:0.4588327408 and Linear_size1 = 6 and Linear_size2 = 12
# The 24 times of test: The RMSE of this test:0.4146138728 and Linear_size1 = 10 and Linear_size2 = 20
# The 25 times of test: The RMSE of this test:0.4329073727 and Linear_size1 = 10 and Linear_size2 = 19
# The 26 times of test: The RMSE of this test:0.4434360862 and Linear_size1 = 10 and Linear_size2 = 18
# The 27 times of test: The RMSE of this test:0.4415461421 and Linear_size1 = 10 and Linear_size2 = 17
# The 28 times of test: The RMSE of this test:0.4656135440 and Linear_size1 = 10 and Linear_size2 = 16
# The 29 times of test: The RMSE of this test:0.4278943837 and Linear_size1 = 10 and Linear_size2 = 15
# The 30 times of test: The RMSE of this test:0.4199262261 and Linear_size1 = 10 and Linear_size2 = 14
# The 31 times of test: The RMSE of this test:0.4346034527 and Linear_size1 = 10 and Linear_size2 = 13
# The 32 times of test: The RMSE of this test:0.4525608718 and Linear_size1 = 10 and Linear_size2 = 12
# The 33 times of test: The RMSE of this test:0.4087356627 and Linear_size1 = 9 and Linear_size2 = 20
# The 34 times of test: The RMSE of this test:0.3900443017 and Linear_size1 = 9 and Linear_size2 = 19
# The 35 times of test: The RMSE of this test:0.4205909967 and Linear_size1 = 9 and Linear_size2 = 18
# The 36 times of test: The RMSE of this test:0.4506056309 and Linear_size1 = 9 and Linear_size2 = 17
# The 37 times of test: The RMSE of this test:0.4395380318 and Linear_size1 = 9 and Linear_size2 = 16
# The 38 times of test: The RMSE of this test:0.4505283237 and Linear_size1 = 9 and Linear_size2 = 15
# The 39 times of test: The RMSE of this test:0.4701374173 and Linear_size1 = 9 and Linear_size2 = 14
# The 40 times of test: The RMSE of this test:0.4337746501 and Linear_size1 = 9 and Linear_size2 = 13
# The 41 times of test: The RMSE of this test:0.4921226203 and Linear_size1 = 9 and Linear_size2 = 12
# The 42 times of test: The RMSE of this test:0.4182296693 and Linear_size1 = 8 and Linear_size2 = 20
# The 43 times of test: The RMSE of this test:0.5091300607 and Linear_size1 = 8 and Linear_size2 = 19
# The 44 times of test: The RMSE of this test:0.4454137087 and Linear_size1 = 8 and Linear_size2 = 18
# The 45 times of test: The RMSE of this test:0.4422085285 and Linear_size1 = 8 and Linear_size2 = 17
# The 46 times of test: The RMSE of this test:0.4227044582 and Linear_size1 = 8 and Linear_size2 = 16
# The 47 times of test: The RMSE of this test:0.4522664845 and Linear_size1 = 8 and Linear_size2 = 15
# The 48 times of test: The RMSE of this test:0.4423151612 and Linear_size1 = 8 and Linear_size2 = 14
# The 49 times of test: The RMSE of this test:0.4676740170 and Linear_size1 = 8 and Linear_size2 = 13
# The 50 times of test: The RMSE of this test:0.4258252680 and Linear_size1 = 8 and Linear_size2 = 12
# The 51 times of test: The RMSE of this test:0.6102204323 and Linear_size1 = 7 and Linear_size2 = 20
# The 52 times of test: The RMSE of this test:0.4106035829 and Linear_size1 = 7 and Linear_size2 = 19
# The 53 times of test: The RMSE of this test:0.4220555127 and Linear_size1 = 7 and Linear_size2 = 18
# The 54 times of test: The RMSE of this test:0.4802474678 and Linear_size1 = 7 and Linear_size2 = 17
# The 55 times of test: The RMSE of this test:0.5434036851 and Linear_size1 = 7 and Linear_size2 = 16
# The 56 times of test: The RMSE of this test:0.4909292161 and Linear_size1 = 7 and Linear_size2 = 15
# The 57 times of test: The RMSE of this test:0.4844540656 and Linear_size1 = 7 and Linear_size2 = 14
# The 58 times of test: The RMSE of this test:0.4213971794 and Linear_size1 = 7 and Linear_size2 = 13
# The 59 times of test: The RMSE of this test:0.4202625155 and Linear_size1 = 7 and Linear_size2 = 12
# The 60 times of test: The RMSE of this test:0.4603356421 and Linear_size1 = 6 and Linear_size2 = 20
# The 61 times of test: The RMSE of this test:0.4509927630 and Linear_size1 = 6 and Linear_size2 = 19
# The 62 times of test: The RMSE of this test:0.4656449854 and Linear_size1 = 6 and Linear_size2 = 18
# The 63 times of test: The RMSE of this test:0.5075598359 and Linear_size1 = 6 and Linear_size2 = 17
# The 64 times of test: The RMSE of this test:0.3972792625 and Linear_size1 = 6 and Linear_size2 = 16
# The 65 times of test: The RMSE of this test:0.3999788761 and Linear_size1 = 6 and Linear_size2 = 15
# The 66 times of test: The RMSE of this test:0.4471071064 and Linear_size1 = 6 and Linear_size2 = 14
# The 67 times of test: The RMSE of this test:0.4732679725 and Linear_size1 = 6 and Linear_size2 = 13
# The 68 times of test: The RMSE of this test:0.4370305538 and Linear_size1 = 6 and Linear_size2 = 12
# The 69 times of test: The RMSE of this test:0.4359243512 and Linear_size1 = 10 and Linear_size2 = 20
# The 70 times of test: The RMSE of this test:0.4409177005 and Linear_size1 = 10 and Linear_size2 = 19
# The 71 times of test: The RMSE of this test:0.4329997301 and Linear_size1 = 10 and Linear_size2 = 18
# The 72 times of test: The RMSE of this test:0.4530788660 and Linear_size1 = 10 and Linear_size2 = 17
# The 73 times of test: The RMSE of this test:0.4493784010 and Linear_size1 = 10 and Linear_size2 = 16
# The 74 times of test: The RMSE of this test:0.3979653120 and Linear_size1 = 10 and Linear_size2 = 15
# The 75 times of test: The RMSE of this test:0.4189467430 and Linear_size1 = 10 and Linear_size2 = 14
# The 76 times of test: The RMSE of this test:0.5090956688 and Linear_size1 = 10 and Linear_size2 = 13
# The 77 times of test: The RMSE of this test:0.4068858922 and Linear_size1 = 10 and Linear_size2 = 12
# The 78 times of test: The RMSE of this test:0.5379342437 and Linear_size1 = 9 and Linear_size2 = 20
# The 79 times of test: The RMSE of this test:0.4316693544 and Linear_size1 = 9 and Linear_size2 = 19
# The 80 times of test: The RMSE of this test:0.4268014431 and Linear_size1 = 9 and Linear_size2 = 18
# The 81 times of test: The RMSE of this test:0.4248172939 and Linear_size1 = 9 and Linear_size2 = 17
# The 82 times of test: The RMSE of this test:0.4799532294 and Linear_size1 = 9 and Linear_size2 = 16
# The 83 times of test: The RMSE of this test:0.4930144250 and Linear_size1 = 9 and Linear_size2 = 15
# The 84 times of test: The RMSE of this test:0.4305295944 and Linear_size1 = 9 and Linear_size2 = 14
# The 85 times of test: The RMSE of this test:0.4532377124 and Linear_size1 = 9 and Linear_size2 = 13
# The 86 times of test: The RMSE of this test:0.4728571177 and Linear_size1 = 9 and Linear_size2 = 12
# The 87 times of test: The RMSE of this test:0.4102465510 and Linear_size1 = 8 and Linear_size2 = 20
# The 88 times of test: The RMSE of this test:0.4502910972 and Linear_size1 = 8 and Linear_size2 = 19
# The 89 times of test: The RMSE of this test:0.4598614872 and Linear_size1 = 8 and Linear_size2 = 18
# The 90 times of test: The RMSE of this test:0.5155286193 and Linear_size1 = 8 and Linear_size2 = 17
# The 91 times of test: The RMSE of this test:0.3976243138 and Linear_size1 = 8 and Linear_size2 = 16
# The 92 times of test: The RMSE of this test:0.5488129854 and Linear_size1 = 8 and Linear_size2 = 15
# The 93 times of test: The RMSE of this test:0.4495222867 and Linear_size1 = 8 and Linear_size2 = 14
# The 94 times of test: The RMSE of this test:0.4121911824 and Linear_size1 = 8 and Linear_size2 = 13
# The 95 times of test: The RMSE of this test:0.4605869055 and Linear_size1 = 8 and Linear_size2 = 12
# The 96 times of test: The RMSE of this test:0.4138174653 and Linear_size1 = 7 and Linear_size2 = 20
# The 97 times of test: The RMSE of this test:0.4586482942 and Linear_size1 = 7 and Linear_size2 = 19
# The 98 times of test: The RMSE of this test:0.4320970476 and Linear_size1 = 7 and Linear_size2 = 18
# The 99 times of test: The RMSE of this test:0.4123058021 and Linear_size1 = 7 and Linear_size2 = 17
# The 100 times of test: The RMSE of this test:0.6189448833 and Linear_size1 = 7 and Linear_size2 = 16
# The 101 times of test: The RMSE of this test:0.4294871390 and Linear_size1 = 7 and Linear_size2 = 15
# The 102 times of test: The RMSE of this test:0.4138920307 and Linear_size1 = 7 and Linear_size2 = 14
# The 103 times of test: The RMSE of this test:0.5034902692 and Linear_size1 = 7 and Linear_size2 = 13
# The 104 times of test: The RMSE of this test:0.5721324086 and Linear_size1 = 7 and Linear_size2 = 12
# The 105 times of test: The RMSE of this test:0.4713326395 and Linear_size1 = 6 and Linear_size2 = 20
# The 106 times of test: The RMSE of this test:0.4580436647 and Linear_size1 = 6 and Linear_size2 = 19
# The 107 times of test: The RMSE of this test:0.4399916232 and Linear_size1 = 6 and Linear_size2 = 18
# The 108 times of test: The RMSE of this test:0.4801245034 and Linear_size1 = 6 and Linear_size2 = 17
# The 109 times of test: The RMSE of this test:0.4914137721 and Linear_size1 = 6 and Linear_size2 = 16
# The 110 times of test: The RMSE of this test:0.4353638589 and Linear_size1 = 6 and Linear_size2 = 15
# The 111 times of test: The RMSE of this test:0.4661682248 and Linear_size1 = 6 and Linear_size2 = 14
# The 112 times of test: The RMSE of this test:0.4993134141 and Linear_size1 = 6 and Linear_size2 = 13
# The 113 times of test: The RMSE of this test:0.5548654199 and Linear_size1 = 6 and Linear_size2 = 12
# The 114 times of test: The RMSE of this test:0.4193474054 and Linear_size1 = 10 and Linear_size2 = 20
# The 115 times of test: The RMSE of this test:0.4569217861 and Linear_size1 = 10 and Linear_size2 = 19
# The 116 times of test: The RMSE of this test:0.4620636702 and Linear_size1 = 10 and Linear_size2 = 18
# The 117 times of test: The RMSE of this test:0.4483104348 and Linear_size1 = 10 and Linear_size2 = 17
# The 118 times of test: The RMSE of this test:0.4367077649 and Linear_size1 = 10 and Linear_size2 = 16
# The 119 times of test: The RMSE of this test:0.4726236761 and Linear_size1 = 10 and Linear_size2 = 15
# The 120 times of test: The RMSE of this test:0.4456320107 and Linear_size1 = 10 and Linear_size2 = 14
# The 121 times of test: The RMSE of this test:0.4130762815 and Linear_size1 = 10 and Linear_size2 = 13
# The 122 times of test: The RMSE of this test:0.5380297303 and Linear_size1 = 10 and Linear_size2 = 12
# The 123 times of test: The RMSE of this test:0.4492093623 and Linear_size1 = 9 and Linear_size2 = 20
# The 124 times of test: The RMSE of this test:0.4751838446 and Linear_size1 = 9 and Linear_size2 = 19
# The 125 times of test: The RMSE of this test:0.5417262912 and Linear_size1 = 9 and Linear_size2 = 18
# The 126 times of test: The RMSE of this test:0.4495823383 and Linear_size1 = 9 and Linear_size2 = 17
# The 127 times of test: The RMSE of this test:0.4512391686 and Linear_size1 = 9 and Linear_size2 = 16
# The 128 times of test: The RMSE of this test:0.4875178635 and Linear_size1 = 9 and Linear_size2 = 15
# The 129 times of test: The RMSE of this test:0.4116840661 and Linear_size1 = 9 and Linear_size2 = 14
# The 130 times of test: The RMSE of this test:0.4603300989 and Linear_size1 = 9 and Linear_size2 = 13
# The 131 times of test: The RMSE of this test:0.5038225651 and Linear_size1 = 9 and Linear_size2 = 12
# The 132 times of test: The RMSE of this test:0.5038397908 and Linear_size1 = 8 and Linear_size2 = 20
# The 133 times of test: The RMSE of this test:0.4356570542 and Linear_size1 = 8 and Linear_size2 = 19
# The 134 times of test: The RMSE of this test:0.4411588609 and Linear_size1 = 8 and Linear_size2 = 18
# The 135 times of test: The RMSE of this test:0.4597726464 and Linear_size1 = 8 and Linear_size2 = 17
# The 136 times of test: The RMSE of this test:0.4504132867 and Linear_size1 = 8 and Linear_size2 = 16
# The 137 times of test: The RMSE of this test:0.4372072816 and Linear_size1 = 8 and Linear_size2 = 15
# The 138 times of test: The RMSE of this test:0.5010634661 and Linear_size1 = 8 and Linear_size2 = 14
# The 139 times of test: The RMSE of this test:0.4456432164 and Linear_size1 = 8 and Linear_size2 = 13
# The 140 times of test: The RMSE of this test:0.3733246922 and Linear_size1 = 8 and Linear_size2 = 12
# The 141 times of test: The RMSE of this test:0.4139108956 and Linear_size1 = 7 and Linear_size2 = 20
# The 142 times of test: The RMSE of this test:0.4580703378 and Linear_size1 = 7 and Linear_size2 = 19
# The 143 times of test: The RMSE of this test:0.4458801746 and Linear_size1 = 7 and Linear_size2 = 18
# The 144 times of test: The RMSE of this test:0.4118129015 and Linear_size1 = 7 and Linear_size2 = 17
# The 145 times of test: The RMSE of this test:0.4093630612 and Linear_size1 = 7 and Linear_size2 = 16
# The 146 times of test: The RMSE of this test:0.4768827856 and Linear_size1 = 7 and Linear_size2 = 15
# The 147 times of test: The RMSE of this test:0.4188640416 and Linear_size1 = 7 and Linear_size2 = 14
# The 148 times of test: The RMSE of this test:0.4627395272 and Linear_size1 = 7 and Linear_size2 = 13
# The 149 times of test: The RMSE of this test:0.5561622977 and Linear_size1 = 7 and Linear_size2 = 12
# The 150 times of test: The RMSE of this test:0.4466344714 and Linear_size1 = 6 and Linear_size2 = 20
# The 151 times of test: The RMSE of this test:0.4309008420 and Linear_size1 = 6 and Linear_size2 = 19
# The 152 times of test: The RMSE of this test:0.4384265244 and Linear_size1 = 6 and Linear_size2 = 18
# The 153 times of test: The RMSE of this test:0.4891025722 and Linear_size1 = 6 and Linear_size2 = 17
# The 154 times of test: The RMSE of this test:0.4252271056 and Linear_size1 = 6 and Linear_size2 = 16
# The 155 times of test: The RMSE of this test:0.4054608643 and Linear_size1 = 6 and Linear_size2 = 15
# The 156 times of test: The RMSE of this test:0.4581401348 and Linear_size1 = 6 and Linear_size2 = 14
# The 157 times of test: The RMSE of this test:0.4358775318 and Linear_size1 = 6 and Linear_size2 = 13
# The 158 times of test: The RMSE of this test:0.5548417568 and Linear_size1 = 6 and Linear_size2 = 12
# The 159 times of test: The RMSE of this test:0.4053974152 and Linear_size1 = 10 and Linear_size2 = 20
# The 160 times of test: The RMSE of this test:0.4037141800 and Linear_size1 = 10 and Linear_size2 = 19
# The 161 times of test: The RMSE of this test:0.4459969997 and Linear_size1 = 10 and Linear_size2 = 18
# The 162 times of test: The RMSE of this test:0.4277486801 and Linear_size1 = 10 and Linear_size2 = 17
# The 163 times of test: The RMSE of this test:0.5825951099 and Linear_size1 = 10 and Linear_size2 = 16
# The 164 times of test: The RMSE of this test:0.4076136351 and Linear_size1 = 10 and Linear_size2 = 15
# The 165 times of test: The RMSE of this test:0.4424942732 and Linear_size1 = 10 and Linear_size2 = 14
# The 166 times of test: The RMSE of this test:0.4195626378 and Linear_size1 = 10 and Linear_size2 = 13
# The 167 times of test: The RMSE of this test:0.4553773701 and Linear_size1 = 10 and Linear_size2 = 12
# The 168 times of test: The RMSE of this test:0.4661833942 and Linear_size1 = 9 and Linear_size2 = 20
# The 169 times of test: The RMSE of this test:0.4725581706 and Linear_size1 = 9 and Linear_size2 = 19
# The 170 times of test: The RMSE of this test:0.4416872561 and Linear_size1 = 9 and Linear_size2 = 18
# The 171 times of test: The RMSE of this test:0.4638789892 and Linear_size1 = 9 and Linear_size2 = 17
# The 172 times of test: The RMSE of this test:0.4261357784 and Linear_size1 = 9 and Linear_size2 = 16
# The 173 times of test: The RMSE of this test:0.4431829453 and Linear_size1 = 9 and Linear_size2 = 15
# The 174 times of test: The RMSE of this test:0.4390777051 and Linear_size1 = 9 and Linear_size2 = 14
# The 175 times of test: The RMSE of this test:0.4506777525 and Linear_size1 = 9 and Linear_size2 = 13
# The 176 times of test: The RMSE of this test:0.4598837197 and Linear_size1 = 9 and Linear_size2 = 12
# The 177 times of test: The RMSE of this test:0.4379449785 and Linear_size1 = 8 and Linear_size2 = 20
# The 178 times of test: The RMSE of this test:0.4351170361 and Linear_size1 = 8 and Linear_size2 = 19
# The 179 times of test: The RMSE of this test:0.4672905803 and Linear_size1 = 8 and Linear_size2 = 18
# The 180 times of test: The RMSE of this test:0.4444138706 and Linear_size1 = 8 and Linear_size2 = 17
# The 181 times of test: The RMSE of this test:0.4346355498 and Linear_size1 = 8 and Linear_size2 = 16
# The 182 times of test: The RMSE of this test:0.4474746585 and Linear_size1 = 8 and Linear_size2 = 15
# The 183 times of test: The RMSE of this test:0.5141003132 and Linear_size1 = 8 and Linear_size2 = 14
# The 184 times of test: The RMSE of this test:0.6004460454 and Linear_size1 = 8 and Linear_size2 = 13
# The 185 times of test: The RMSE of this test:0.4283164740 and Linear_size1 = 8 and Linear_size2 = 12
# The 186 times of test: The RMSE of this test:0.4372836053 and Linear_size1 = 7 and Linear_size2 = 20
# The 187 times of test: The RMSE of this test:0.4202136993 and Linear_size1 = 7 and Linear_size2 = 19
# The 188 times of test: The RMSE of this test:0.4456426799 and Linear_size1 = 7 and Linear_size2 = 18
# The 189 times of test: The RMSE of this test:0.4466992319 and Linear_size1 = 7 and Linear_size2 = 17
# The 190 times of test: The RMSE of this test:0.4880672097 and Linear_size1 = 7 and Linear_size2 = 16
# The 191 times of test: The RMSE of this test:0.5122424960 and Linear_size1 = 7 and Linear_size2 = 15
# The 192 times of test: The RMSE of this test:0.6477272511 and Linear_size1 = 7 and Linear_size2 = 14
# The 193 times of test: The RMSE of this test:0.5925120115 and Linear_size1 = 7 and Linear_size2 = 13
# The 194 times of test: The RMSE of this test:0.4940307438 and Linear_size1 = 7 and Linear_size2 = 12
# The 195 times of test: The RMSE of this test:0.3945597112 and Linear_size1 = 6 and Linear_size2 = 20
# The 196 times of test: The RMSE of this test:0.4150875211 and Linear_size1 = 6 and Linear_size2 = 19
# The 197 times of test: The RMSE of this test:0.4171693325 and Linear_size1 = 6 and Linear_size2 = 18
# The 198 times of test: The RMSE of this test:0.5436002612 and Linear_size1 = 6 and Linear_size2 = 17
# The 199 times of test: The RMSE of this test:0.4782510102 and Linear_size1 = 6 and Linear_size2 = 16
# The 200 times of test: The RMSE of this test:0.4304878712 and Linear_size1 = 6 and Linear_size2 = 15
# The 201 times of test: The RMSE of this test:0.4306872487 and Linear_size1 = 6 and Linear_size2 = 14
# The 202 times of test: The RMSE of this test:0.4029477835 and Linear_size1 = 6 and Linear_size2 = 13
# The 203 times of test: The RMSE of this test:0.4185161293 and Linear_size1 = 6 and Linear_size2 = 12
# The 204 times of test: The RMSE of this test:0.7810888290 and Linear_size1 = 10 and Linear_size2 = 20
# The 205 times of test: The RMSE of this test:0.4207061529 and Linear_size1 = 10 and Linear_size2 = 19
# The 206 times of test: The RMSE of this test:0.4495890737 and Linear_size1 = 10 and Linear_size2 = 18
# The 207 times of test: The RMSE of this test:0.4572418928 and Linear_size1 = 10 and Linear_size2 = 17
# The 208 times of test: The RMSE of this test:0.4804750085 and Linear_size1 = 10 and Linear_size2 = 16
# The 209 times of test: The RMSE of this test:0.4153697193 and Linear_size1 = 10 and Linear_size2 = 15
# The 210 times of test: The RMSE of this test:0.4029651284 and Linear_size1 = 10 and Linear_size2 = 14
# The 211 times of test: The RMSE of this test:0.4558476806 and Linear_size1 = 10 and Linear_size2 = 13
# The 212 times of test: The RMSE of this test:0.4613881707 and Linear_size1 = 10 and Linear_size2 = 12
# The 213 times of test: The RMSE of this test:0.3920443356 and Linear_size1 = 9 and Linear_size2 = 20
# The 214 times of test: The RMSE of this test:0.4089076519 and Linear_size1 = 9 and Linear_size2 = 19
# The 215 times of test: The RMSE of this test:0.4492268562 and Linear_size1 = 9 and Linear_size2 = 18
# The 216 times of test: The RMSE of this test:0.4251888394 and Linear_size1 = 9 and Linear_size2 = 17
# The 217 times of test: The RMSE of this test:0.4013916552 and Linear_size1 = 9 and Linear_size2 = 16
# The 218 times of test: The RMSE of this test:0.4400970042 and Linear_size1 = 9 and Linear_size2 = 15
# The 219 times of test: The RMSE of this test:0.4831662178 and Linear_size1 = 9 and Linear_size2 = 14
# The 220 times of test: The RMSE of this test:0.6633163095 and Linear_size1 = 9 and Linear_size2 = 13
# The 221 times of test: The RMSE of this test:0.4325675666 and Linear_size1 = 9 and Linear_size2 = 12
# The 222 times of test: The RMSE of this test:0.4297534525 and Linear_size1 = 8 and Linear_size2 = 20
# The 223 times of test: The RMSE of this test:0.4457189441 and Linear_size1 = 8 and Linear_size2 = 19
# The 224 times of test: The RMSE of this test:0.4537023902 and Linear_size1 = 8 and Linear_size2 = 18
# The 225 times of test: The RMSE of this test:0.4674145877 and Linear_size1 = 8 and Linear_size2 = 17
# The 226 times of test: The RMSE of this test:0.5086190104 and Linear_size1 = 8 and Linear_size2 = 16
# The 227 times of test: The RMSE of this test:0.5442245007 and Linear_size1 = 8 and Linear_size2 = 15
# The 228 times of test: The RMSE of this test:0.4622893929 and Linear_size1 = 8 and Linear_size2 = 14
# The 229 times of test: The RMSE of this test:0.4500036538 and Linear_size1 = 8 and Linear_size2 = 13
# The 230 times of test: The RMSE of this test:0.4196575880 and Linear_size1 = 8 and Linear_size2 = 12
# The 231 times of test: The RMSE of this test:0.4771277308 and Linear_size1 = 7 and Linear_size2 = 20
# The 232 times of test: The RMSE of this test:0.4235335588 and Linear_size1 = 7 and Linear_size2 = 19
# The 233 times of test: The RMSE of this test:0.5824333429 and Linear_size1 = 7 and Linear_size2 = 18
# The 234 times of test: The RMSE of this test:0.4918450415 and Linear_size1 = 7 and Linear_size2 = 17
# The 235 times of test: The RMSE of this test:0.4938311577 and Linear_size1 = 7 and Linear_size2 = 16
# The 236 times of test: The RMSE of this test:0.5788296461 and Linear_size1 = 7 and Linear_size2 = 15
# The 237 times of test: The RMSE of this test:0.4510110617 and Linear_size1 = 7 and Linear_size2 = 14
# The 238 times of test: The RMSE of this test:0.4402013421 and Linear_size1 = 7 and Linear_size2 = 13
# The 239 times of test: The RMSE of this test:0.4472418725 and Linear_size1 = 7 and Linear_size2 = 12
# The 240 times of test: The RMSE of this test:0.4046733677 and Linear_size1 = 6 and Linear_size2 = 20
# The 241 times of test: The RMSE of this test:0.4382880330 and Linear_size1 = 6 and Linear_size2 = 19
# The 242 times of test: The RMSE of this test:0.4066244662 and Linear_size1 = 6 and Linear_size2 = 18
# The 243 times of test: The RMSE of this test:0.4637104571 and Linear_size1 = 6 and Linear_size2 = 17
# The 244 times of test: The RMSE of this test:0.4289232790 and Linear_size1 = 6 and Linear_size2 = 16
# The 245 times of test: The RMSE of this test:0.4432950020 and Linear_size1 = 6 and Linear_size2 = 15
# The 246 times of test: The RMSE of this test:0.4609622359 and Linear_size1 = 6 and Linear_size2 = 14
# The 247 times of test: The RMSE of this test:0.4967270792 and Linear_size1 = 6 and Linear_size2 = 13
# The 248 times of test: The RMSE of this test:0.5797847509 and Linear_size1 = 6 and Linear_size2 = 12
# The 249 times of test: The RMSE of this test:0.4715625048 and Linear_size1 = 10 and Linear_size2 = 20
# The 250 times of test: The RMSE of this test:0.4679128230 and Linear_size1 = 10 and Linear_size2 = 19
# The 251 times of test: The RMSE of this test:0.5037893653 and Linear_size1 = 10 and Linear_size2 = 18
# The 252 times of test: The RMSE of this test:0.4064733684 and Linear_size1 = 10 and Linear_size2 = 17
# The 253 times of test: The RMSE of this test:0.4266508222 and Linear_size1 = 10 and Linear_size2 = 16
# The 254 times of test: The RMSE of this test:0.3937867284 and Linear_size1 = 10 and Linear_size2 = 15
# The 255 times of test: The RMSE of this test:0.4181189835 and Linear_size1 = 10 and Linear_size2 = 14
# The 256 times of test: The RMSE of this test:0.4313222766 and Linear_size1 = 10 and Linear_size2 = 13
# The 257 times of test: The RMSE of this test:0.4223915040 and Linear_size1 = 10 and Linear_size2 = 12
# The 258 times of test: The RMSE of this test:0.4748184383 and Linear_size1 = 9 and Linear_size2 = 20
# The 259 times of test: The RMSE of this test:0.4841285050 and Linear_size1 = 9 and Linear_size2 = 19
# The 260 times of test: The RMSE of this test:0.4283381402 and Linear_size1 = 9 and Linear_size2 = 18
# The 261 times of test: The RMSE of this test:0.4064686894 and Linear_size1 = 9 and Linear_size2 = 17
# The 262 times of test: The RMSE of this test:0.4022223651 and Linear_size1 = 9 and Linear_size2 = 16
# The 263 times of test: The RMSE of this test:0.4324775338 and Linear_size1 = 9 and Linear_size2 = 15
# The 264 times of test: The RMSE of this test:0.4724920690 and Linear_size1 = 9 and Linear_size2 = 14
# The 265 times of test: The RMSE of this test:0.4550237358 and Linear_size1 = 9 and Linear_size2 = 13
# The 266 times of test: The RMSE of this test:0.4777566493 and Linear_size1 = 9 and Linear_size2 = 12
# The 267 times of test: The RMSE of this test:0.4656385779 and Linear_size1 = 8 and Linear_size2 = 20
# The 268 times of test: The RMSE of this test:0.4360764325 and Linear_size1 = 8 and Linear_size2 = 19
# The 269 times of test: The RMSE of this test:0.4813558459 and Linear_size1 = 8 and Linear_size2 = 18
# The 270 times of test: The RMSE of this test:0.4065621793 and Linear_size1 = 8 and Linear_size2 = 17
# The 271 times of test: The RMSE of this test:0.4914889932 and Linear_size1 = 8 and Linear_size2 = 16
# The 272 times of test: The RMSE of this test:0.5482508540 and Linear_size1 = 8 and Linear_size2 = 15
# The 273 times of test: The RMSE of this test:0.6030392647 and Linear_size1 = 8 and Linear_size2 = 14
# The 274 times of test: The RMSE of this test:0.4372944832 and Linear_size1 = 8 and Linear_size2 = 13
# The 275 times of test: The RMSE of this test:0.4301759601 and Linear_size1 = 8 and Linear_size2 = 12
# The 276 times of test: The RMSE of this test:0.4490234554 and Linear_size1 = 7 and Linear_size2 = 20
# The 277 times of test: The RMSE of this test:0.4280371964 and Linear_size1 = 7 and Linear_size2 = 19
# The 278 times of test: The RMSE of this test:0.5078558326 and Linear_size1 = 7 and Linear_size2 = 18
# The 279 times of test: The RMSE of this test:0.4300187230 and Linear_size1 = 7 and Linear_size2 = 17
# The 280 times of test: The RMSE of this test:0.4605462849 and Linear_size1 = 7 and Linear_size2 = 16
# The 281 times of test: The RMSE of this test:0.3939391971 and Linear_size1 = 7 and Linear_size2 = 15
# The 282 times of test: The RMSE of this test:0.4905894101 and Linear_size1 = 7 and Linear_size2 = 14
# The 283 times of test: The RMSE of this test:0.5122192502 and Linear_size1 = 7 and Linear_size2 = 13
# The 284 times of test: The RMSE of this test:0.4736675620 and Linear_size1 = 7 and Linear_size2 = 12
# The 285 times of test: The RMSE of this test:0.4999195635 and Linear_size1 = 6 and Linear_size2 = 20
# The 286 times of test: The RMSE of this test:0.4173383713 and Linear_size1 = 6 and Linear_size2 = 19
# The 287 times of test: The RMSE of this test:0.4161985517 and Linear_size1 = 6 and Linear_size2 = 18
# The 288 times of test: The RMSE of this test:0.4182373583 and Linear_size1 = 6 and Linear_size2 = 17
# The 289 times of test: The RMSE of this test:0.4172162712 and Linear_size1 = 6 and Linear_size2 = 16
# The 290 times of test: The RMSE of this test:0.4390718043 and Linear_size1 = 6 and Linear_size2 = 15
# The 291 times of test: The RMSE of this test:0.3794440031 and Linear_size1 = 6 and Linear_size2 = 14
# The 292 times of test: The RMSE of this test:0.4338986874 and Linear_size1 = 6 and Linear_size2 = 13
# The 293 times of test: The RMSE of this test:0.4837745726 and Linear_size1 = 6 and Linear_size2 = 12
# The 294 times of test: The RMSE of this test:0.4696553349 and Linear_size1 = 10 and Linear_size2 = 20
# The 295 times of test: The RMSE of this test:0.4542669952 and Linear_size1 = 10 and Linear_size2 = 19
# The 296 times of test: The RMSE of this test:0.4094415307 and Linear_size1 = 10 and Linear_size2 = 18
# The 297 times of test: The RMSE of this test:0.4771069288 and Linear_size1 = 10 and Linear_size2 = 17
# The 298 times of test: The RMSE of this test:0.5182426572 and Linear_size1 = 10 and Linear_size2 = 16
# The 299 times of test: The RMSE of this test:0.4314515591 and Linear_size1 = 10 and Linear_size2 = 15
# The 300 times of test: The RMSE of this test:0.6647192240 and Linear_size1 = 10 and Linear_size2 = 14
# The 301 times of test: The RMSE of this test:0.4874419868 and Linear_size1 = 10 and Linear_size2 = 13
# The 302 times of test: The RMSE of this test:0.6512276530 and Linear_size1 = 10 and Linear_size2 = 12
# The 303 times of test: The RMSE of this test:0.4355256855 and Linear_size1 = 9 and Linear_size2 = 20
# The 304 times of test: The RMSE of this test:0.4238968492 and Linear_size1 = 9 and Linear_size2 = 19
# The 305 times of test: The RMSE of this test:0.4206626117 and Linear_size1 = 9 and Linear_size2 = 18
# The 306 times of test: The RMSE of this test:0.4109139740 and Linear_size1 = 9 and Linear_size2 = 17
# The 307 times of test: The RMSE of this test:0.4730746150 and Linear_size1 = 9 and Linear_size2 = 16
# The 308 times of test: The RMSE of this test:0.4045400620 and Linear_size1 = 9 and Linear_size2 = 15
# The 309 times of test: The RMSE of this test:0.4409514964 and Linear_size1 = 9 and Linear_size2 = 14
# The 310 times of test: The RMSE of this test:0.4660410285 and Linear_size1 = 9 and Linear_size2 = 13
# The 311 times of test: The RMSE of this test:0.4914518297 and Linear_size1 = 9 and Linear_size2 = 12
# The 312 times of test: The RMSE of this test:0.4325598776 and Linear_size1 = 8 and Linear_size2 = 20
# The 313 times of test: The RMSE of this test:0.5745437741 and Linear_size1 = 8 and Linear_size2 = 19
# The 314 times of test: The RMSE of this test:0.4686057866 and Linear_size1 = 8 and Linear_size2 = 18
# The 315 times of test: The RMSE of this test:0.4444335699 and Linear_size1 = 8 and Linear_size2 = 17
# The 316 times of test: The RMSE of this test:0.5561313033 and Linear_size1 = 8 and Linear_size2 = 16
# The 317 times of test: The RMSE of this test:0.4373329282 and Linear_size1 = 8 and Linear_size2 = 15
# The 318 times of test: The RMSE of this test:0.5004665256 and Linear_size1 = 8 and Linear_size2 = 14
# The 319 times of test: The RMSE of this test:0.4567496181 and Linear_size1 = 8 and Linear_size2 = 13
# The 320 times of test: The RMSE of this test:0.4307401776 and Linear_size1 = 8 and Linear_size2 = 12
# The 321 times of test: The RMSE of this test:0.4698510766 and Linear_size1 = 7 and Linear_size2 = 20
# The 322 times of test: The RMSE of this test:0.4765707850 and Linear_size1 = 7 and Linear_size2 = 19
# The 323 times of test: The RMSE of this test:0.3726212084 and Linear_size1 = 7 and Linear_size2 = 18
# The 324 times of test: The RMSE of this test:0.5152464509 and Linear_size1 = 7 and Linear_size2 = 17
# The 325 times of test: The RMSE of this test:0.4721997678 and Linear_size1 = 7 and Linear_size2 = 16
# The 326 times of test: The RMSE of this test:0.4373610318 and Linear_size1 = 7 and Linear_size2 = 15
# The 327 times of test: The RMSE of this test:0.4319607615 and Linear_size1 = 7 and Linear_size2 = 14
# The 328 times of test: The RMSE of this test:0.4924673736 and Linear_size1 = 7 and Linear_size2 = 13
# The 329 times of test: The RMSE of this test:0.4628403485 and Linear_size1 = 7 and Linear_size2 = 12
# The 330 times of test: The RMSE of this test:0.4259828627 and Linear_size1 = 6 and Linear_size2 = 20
# The 331 times of test: The RMSE of this test:0.4509930015 and Linear_size1 = 6 and Linear_size2 = 19
# The 332 times of test: The RMSE of this test:0.4265431166 and Linear_size1 = 6 and Linear_size2 = 18
# The 333 times of test: The RMSE of this test:0.4857818484 and Linear_size1 = 6 and Linear_size2 = 17
# The 334 times of test: The RMSE of this test:0.4918338060 and Linear_size1 = 6 and Linear_size2 = 16
# The 335 times of test: The RMSE of this test:0.4529238045 and Linear_size1 = 6 and Linear_size2 = 15
# The 336 times of test: The RMSE of this test:0.4587503374 and Linear_size1 = 6 and Linear_size2 = 14
# The 337 times of test: The RMSE of this test:0.4758610427 and Linear_size1 = 6 and Linear_size2 = 13
# The 338 times of test: The RMSE of this test:0.5428535342 and Linear_size1 = 6 and Linear_size2 = 12
# The 339 times of test: The RMSE of this test:0.4932746887 and Linear_size1 = 10 and Linear_size2 = 20
# The 340 times of test: The RMSE of this test:0.4332801998 and Linear_size1 = 10 and Linear_size2 = 19
# The 341 times of test: The RMSE of this test:0.4467757046 and Linear_size1 = 10 and Linear_size2 = 18
# The 342 times of test: The RMSE of this test:0.4629077315 and Linear_size1 = 10 and Linear_size2 = 17
# The 343 times of test: The RMSE of this test:0.4512923360 and Linear_size1 = 10 and Linear_size2 = 16
# The 344 times of test: The RMSE of this test:0.4226781726 and Linear_size1 = 10 and Linear_size2 = 15
# The 345 times of test: The RMSE of this test:0.4447453618 and Linear_size1 = 10 and Linear_size2 = 14
# The 346 times of test: The RMSE of this test:0.4362295270 and Linear_size1 = 10 and Linear_size2 = 13
# The 347 times of test: The RMSE of this test:0.4862913787 and Linear_size1 = 10 and Linear_size2 = 12
# The 348 times of test: The RMSE of this test:0.5119157434 and Linear_size1 = 9 and Linear_size2 = 20
# The 349 times of test: The RMSE of this test:0.4141737819 and Linear_size1 = 9 and Linear_size2 = 19
# The 350 times of test: The RMSE of this test:0.4149866700 and Linear_size1 = 9 and Linear_size2 = 18
# The 351 times of test: The RMSE of this test:0.4162761867 and Linear_size1 = 9 and Linear_size2 = 17
# The 352 times of test: The RMSE of this test:0.4400989413 and Linear_size1 = 9 and Linear_size2 = 16
# The 353 times of test: The RMSE of this test:0.4440825880 and Linear_size1 = 9 and Linear_size2 = 15
# The 354 times of test: The RMSE of this test:0.4499139190 and Linear_size1 = 9 and Linear_size2 = 14
# The 355 times of test: The RMSE of this test:0.5229166150 and Linear_size1 = 9 and Linear_size2 = 13
# The 356 times of test: The RMSE of this test:0.4857892692 and Linear_size1 = 9 and Linear_size2 = 12
# The 357 times of test: The RMSE of this test:0.4417349398 and Linear_size1 = 8 and Linear_size2 = 20
# The 358 times of test: The RMSE of this test:0.5743915439 and Linear_size1 = 8 and Linear_size2 = 19
# The 359 times of test: The RMSE of this test:0.4734159410 and Linear_size1 = 8 and Linear_size2 = 18
# The 360 times of test: The RMSE of this test:0.4981536567 and Linear_size1 = 8 and Linear_size2 = 17
# The 361 times of test: The RMSE of this test:0.4073656201 and Linear_size1 = 8 and Linear_size2 = 16
# The 362 times of test: The RMSE of this test:0.5980470777 and Linear_size1 = 8 and Linear_size2 = 15
# The 363 times of test: The RMSE of this test:0.4992320240 and Linear_size1 = 8 and Linear_size2 = 14
# The 364 times of test: The RMSE of this test:0.5658134818 and Linear_size1 = 8 and Linear_size2 = 13
# The 365 times of test: The RMSE of this test:0.4746500850 and Linear_size1 = 8 and Linear_size2 = 12
# The 366 times of test: The RMSE of this test:0.4309220612 and Linear_size1 = 7 and Linear_size2 = 20
# The 367 times of test: The RMSE of this test:0.4550609589 and Linear_size1 = 7 and Linear_size2 = 19
# The 368 times of test: The RMSE of this test:0.4582709074 and Linear_size1 = 7 and Linear_size2 = 18
# The 369 times of test: The RMSE of this test:0.4798072875 and Linear_size1 = 7 and Linear_size2 = 17
# The 370 times of test: The RMSE of this test:0.4335786998 and Linear_size1 = 7 and Linear_size2 = 16
# The 371 times of test: The RMSE of this test:0.4663486779 and Linear_size1 = 7 and Linear_size2 = 15
# The 372 times of test: The RMSE of this test:0.4253858626 and Linear_size1 = 7 and Linear_size2 = 14
# The 373 times of test: The RMSE of this test:0.4446166754 and Linear_size1 = 7 and Linear_size2 = 13
# The 374 times of test: The RMSE of this test:0.5139245987 and Linear_size1 = 7 and Linear_size2 = 12
# The 375 times of test: The RMSE of this test:0.4451450408 and Linear_size1 = 6 and Linear_size2 = 20
# The 376 times of test: The RMSE of this test:0.4442401230 and Linear_size1 = 6 and Linear_size2 = 19
# The 377 times of test: The RMSE of this test:0.4412418902 and Linear_size1 = 6 and Linear_size2 = 18
# The 378 times of test: The RMSE of this test:0.4366243184 and Linear_size1 = 6 and Linear_size2 = 17
# The 379 times of test: The RMSE of this test:0.4547604918 and Linear_size1 = 6 and Linear_size2 = 16
# The 380 times of test: The RMSE of this test:0.4183729589 and Linear_size1 = 6 and Linear_size2 = 15
# The 381 times of test: The RMSE of this test:0.4334767759 and Linear_size1 = 6 and Linear_size2 = 14
# The 382 times of test: The RMSE of this test:0.4179974794 and Linear_size1 = 6 and Linear_size2 = 13
# The 383 times of test: The RMSE of this test:0.4370769858 and Linear_size1 = 6 and Linear_size2 = 12
# The 384 times of test: The RMSE of this test:0.4593137801 and Linear_size1 = 10 and Linear_size2 = 20
# The 385 times of test: The RMSE of this test:0.4863274992 and Linear_size1 = 10 and Linear_size2 = 19
# The 386 times of test: The RMSE of this test:0.4293427765 and Linear_size1 = 10 and Linear_size2 = 18
# The 387 times of test: The RMSE of this test:0.4089143872 and Linear_size1 = 10 and Linear_size2 = 17
# The 388 times of test: The RMSE of this test:0.5050547719 and Linear_size1 = 10 and Linear_size2 = 16
# The 389 times of test: The RMSE of this test:0.4600378871 and Linear_size1 = 10 and Linear_size2 = 15
# The 390 times of test: The RMSE of this test:0.5316795111 and Linear_size1 = 10 and Linear_size2 = 14
# The 391 times of test: The RMSE of this test:0.4611707330 and Linear_size1 = 10 and Linear_size2 = 13
# The 392 times of test: The RMSE of this test:0.5675911307 and Linear_size1 = 10 and Linear_size2 = 12
# The 393 times of test: The RMSE of this test:0.3978227675 and Linear_size1 = 9 and Linear_size2 = 20
# The 394 times of test: The RMSE of this test:0.4584605396 and Linear_size1 = 9 and Linear_size2 = 19
# The 395 times of test: The RMSE of this test:0.4139932096 and Linear_size1 = 9 and Linear_size2 = 18
# The 396 times of test: The RMSE of this test:0.4476647973 and Linear_size1 = 9 and Linear_size2 = 17
# The 397 times of test: The RMSE of this test:0.4649713635 and Linear_size1 = 9 and Linear_size2 = 16
# The 398 times of test: The RMSE of this test:0.6925435662 and Linear_size1 = 9 and Linear_size2 = 15
# The 399 times of test: The RMSE of this test:0.4486168623 and Linear_size1 = 9 and Linear_size2 = 14
# The 400 times of test: The RMSE of this test:0.4222939014 and Linear_size1 = 9 and Linear_size2 = 13
# The 401 times of test: The RMSE of this test:0.5057524443 and Linear_size1 = 9 and Linear_size2 = 12
# The 402 times of test: The RMSE of this test:0.4305077493 and Linear_size1 = 8 and Linear_size2 = 20
# The 403 times of test: The RMSE of this test:0.4226922393 and Linear_size1 = 8 and Linear_size2 = 19
# The 404 times of test: The RMSE of this test:0.4860922098 and Linear_size1 = 8 and Linear_size2 = 18
# The 405 times of test: The RMSE of this test:0.3971027732 and Linear_size1 = 8 and Linear_size2 = 17
# The 406 times of test: The RMSE of this test:0.4651864767 and Linear_size1 = 8 and Linear_size2 = 16
# The 407 times of test: The RMSE of this test:0.4486483634 and Linear_size1 = 8 and Linear_size2 = 15
# The 408 times of test: The RMSE of this test:0.4530671239 and Linear_size1 = 8 and Linear_size2 = 14
# The 409 times of test: The RMSE of this test:0.5252249241 and Linear_size1 = 8 and Linear_size2 = 13
# The 410 times of test: The RMSE of this test:0.3981938064 and Linear_size1 = 8 and Linear_size2 = 12
# The 411 times of test: The RMSE of this test:0.4279261231 and Linear_size1 = 7 and Linear_size2 = 20
# The 412 times of test: The RMSE of this test:0.3875549138 and Linear_size1 = 7 and Linear_size2 = 19
# The 413 times of test: The RMSE of this test:0.4257048965 and Linear_size1 = 7 and Linear_size2 = 18
# The 414 times of test: The RMSE of this test:0.4627518654 and Linear_size1 = 7 and Linear_size2 = 17
# The 415 times of test: The RMSE of this test:0.4521597624 and Linear_size1 = 7 and Linear_size2 = 16
# The 416 times of test: The RMSE of this test:0.4500193000 and Linear_size1 = 7 and Linear_size2 = 15
# The 417 times of test: The RMSE of this test:0.4262912571 and Linear_size1 = 7 and Linear_size2 = 14
# The 418 times of test: The RMSE of this test:0.5252265930 and Linear_size1 = 7 and Linear_size2 = 13
# The 419 times of test: The RMSE of this test:0.5451847911 and Linear_size1 = 7 and Linear_size2 = 12
# The 420 times of test: The RMSE of this test:0.4017107487 and Linear_size1 = 6 and Linear_size2 = 20
# The 421 times of test: The RMSE of this test:0.5177549720 and Linear_size1 = 6 and Linear_size2 = 19
# The 422 times of test: The RMSE of this test:0.4832402170 and Linear_size1 = 6 and Linear_size2 = 18
# The 423 times of test: The RMSE of this test:0.4286039472 and Linear_size1 = 6 and Linear_size2 = 17
# The 424 times of test: The RMSE of this test:0.4851457775 and Linear_size1 = 6 and Linear_size2 = 16
# The 425 times of test: The RMSE of this test:0.4513249099 and Linear_size1 = 6 and Linear_size2 = 15
# The 426 times of test: The RMSE of this test:0.4593865871 and Linear_size1 = 6 and Linear_size2 = 14
# The 427 times of test: The RMSE of this test:0.4357536137 and Linear_size1 = 6 and Linear_size2 = 13
# The 428 times of test: The RMSE of this test:0.4588892162 and Linear_size1 = 6 and Linear_size2 = 12
# The 429 times of test: The RMSE of this test:0.4272296429 and Linear_size1 = 10 and Linear_size2 = 20
# The 430 times of test: The RMSE of this test:0.4181128144 and Linear_size1 = 10 and Linear_size2 = 19
# The 431 times of test: The RMSE of this test:0.4320507348 and Linear_size1 = 10 and Linear_size2 = 18
# The 432 times of test: The RMSE of this test:0.4412060976 and Linear_size1 = 10 and Linear_size2 = 17
# The 433 times of test: The RMSE of this test:0.8991230726 and Linear_size1 = 10 and Linear_size2 = 16
# The 434 times of test: The RMSE of this test:0.5068766475 and Linear_size1 = 10 and Linear_size2 = 15
# The 435 times of test: The RMSE of this test:0.5062548518 and Linear_size1 = 10 and Linear_size2 = 14
# The 436 times of test: The RMSE of this test:0.5630753636 and Linear_size1 = 10 and Linear_size2 = 13
# The 437 times of test: The RMSE of this test:0.4415685534 and Linear_size1 = 10 and Linear_size2 = 12
# The 438 times of test: The RMSE of this test:0.5130135417 and Linear_size1 = 9 and Linear_size2 = 20
# The 439 times of test: The RMSE of this test:0.3987525702 and Linear_size1 = 9 and Linear_size2 = 19
# The 440 times of test: The RMSE of this test:0.3956484795 and Linear_size1 = 9 and Linear_size2 = 18
# The 441 times of test: The RMSE of this test:0.4209670126 and Linear_size1 = 9 and Linear_size2 = 17
# The 442 times of test: The RMSE of this test:0.4397972226 and Linear_size1 = 9 and Linear_size2 = 16
# The 443 times of test: The RMSE of this test:0.5181785226 and Linear_size1 = 9 and Linear_size2 = 15
# The 444 times of test: The RMSE of this test:0.4172767401 and Linear_size1 = 9 and Linear_size2 = 14
# The 445 times of test: The RMSE of this test:0.4808819294 and Linear_size1 = 9 and Linear_size2 = 13
# The 446 times of test: The RMSE of this test:0.4027153552 and Linear_size1 = 9 and Linear_size2 = 12
# The 447 times of test: The RMSE of this test:0.4422482848 and Linear_size1 = 8 and Linear_size2 = 20
# The 448 times of test: The RMSE of this test:0.4349706471 and Linear_size1 = 8 and Linear_size2 = 19
# The 449 times of test: The RMSE of this test:0.4219651222 and Linear_size1 = 8 and Linear_size2 = 18
# The 450 times of test: The RMSE of this test:0.4815134704 and Linear_size1 = 8 and Linear_size2 = 17
# The 451 times of test: The RMSE of this test:0.5050293207 and Linear_size1 = 8 and Linear_size2 = 16
# The 452 times of test: The RMSE of this test:0.4699006379 and Linear_size1 = 8 and Linear_size2 = 15
# The 453 times of test: The RMSE of this test:0.4089968801 and Linear_size1 = 8 and Linear_size2 = 14
# The 454 times of test: The RMSE of this test:0.4498271346 and Linear_size1 = 8 and Linear_size2 = 13
# The 455 times of test: The RMSE of this test:0.4858189225 and Linear_size1 = 8 and Linear_size2 = 12
# The 456 times of test: The RMSE of this test:0.5061681271 and Linear_size1 = 7 and Linear_size2 = 20
# The 457 times of test: The RMSE of this test:0.5739479065 and Linear_size1 = 7 and Linear_size2 = 19
# The 458 times of test: The RMSE of this test:0.4539530277 and Linear_size1 = 7 and Linear_size2 = 18
# The 459 times of test: The RMSE of this test:0.4929770231 and Linear_size1 = 7 and Linear_size2 = 17
# The 460 times of test: The RMSE of this test:0.4371129572 and Linear_size1 = 7 and Linear_size2 = 16
# The 461 times of test: The RMSE of this test:0.4274133742 and Linear_size1 = 7 and Linear_size2 = 15
# The 462 times of test: The RMSE of this test:0.3928953111 and Linear_size1 = 7 and Linear_size2 = 14
# The 463 times of test: The RMSE of this test:0.4293404222 and Linear_size1 = 7 and Linear_size2 = 13
# The 464 times of test: The RMSE of this test:0.4531106055 and Linear_size1 = 7 and Linear_size2 = 12
# The 465 times of test: The RMSE of this test:0.5400101542 and Linear_size1 = 6 and Linear_size2 = 20
# The 466 times of test: The RMSE of this test:0.4328148961 and Linear_size1 = 6 and Linear_size2 = 19
# The 467 times of test: The RMSE of this test:0.5317819715 and Linear_size1 = 6 and Linear_size2 = 18
# The 468 times of test: The RMSE of this test:0.5198697448 and Linear_size1 = 6 and Linear_size2 = 17
# The 469 times of test: The RMSE of this test:0.5153431892 and Linear_size1 = 6 and Linear_size2 = 16
# The 470 times of test: The RMSE of this test:0.4822243452 and Linear_size1 = 6 and Linear_size2 = 15
# The 471 times of test: The RMSE of this test:0.4887239635 and Linear_size1 = 6 and Linear_size2 = 14
# The 472 times of test: The RMSE of this test:0.4341977835 and Linear_size1 = 6 and Linear_size2 = 13
# The 473 times of test: The RMSE of this test:0.5031456947 and Linear_size1 = 6 and Linear_size2 = 12
# The 474 times of test: The RMSE of this test:0.4274262786 and Linear_size1 = 10 and Linear_size2 = 20
# The 475 times of test: The RMSE of this test:0.4462727308 and Linear_size1 = 10 and Linear_size2 = 19
# ...
# The 1070 times of test: The RMSE of this test:0.4179967642 and Linear_size1 = 9 and Linear_size2 = 18
# The 1071 times of test: The RMSE of this test:0.4400210679 and Linear_size1 = 9 and Linear_size2 = 17
# The 1072 times of test: The RMSE of this test:0.3899490535 and Linear_size1 = 9 and Linear_size2 = 16
# The 1073 times of test: The RMSE of this test:0.5153993368 and Linear_size1 = 9 and Linear_size2 = 15
# The 1074 times of test: The RMSE of this test:0.4338051677 and Linear_size1 = 9 and Linear_size2 = 14
# The 1075 times of test: The RMSE of this test:0.4366506040 and Linear_size1 = 9 and Linear_size2 = 13
# The 1076 times of test: The RMSE of this test:0.4626942575 and Linear_size1 = 9 and Linear_size2 = 12
# The 1077 times of test: The RMSE of this test:0.4145920575 and Linear_size1 = 8 and Linear_size2 = 20
# The 1078 times of test: The RMSE of this test:0.5350862145 and Linear_size1 = 8 and Linear_size2 = 19
# The 1079 times of test: The RMSE of this test:0.4427385032 and Linear_size1 = 8 and Linear_size2 = 18
# The 1080 times of test: The RMSE of this test:0.4499911368 and Linear_size1 = 8 and Linear_size2 = 17
# The 1081 times of test: The RMSE of this test:0.4328106642 and Linear_size1 = 8 and Linear_size2 = 16
# The 1082 times of test: The RMSE of this test:0.4231236577 and Linear_size1 = 8 and Linear_size2 = 15
# The 1083 times of test: The RMSE of this test:0.4318855107 and Linear_size1 = 8 and Linear_size2 = 14
# The 1084 times of test: The RMSE of this test:0.4679014385 and Linear_size1 = 8 and Linear_size2 = 13
# The 1085 times of test: The RMSE of this test:0.4287539423 and Linear_size1 = 8 and Linear_size2 = 12
# The 1086 times of test: The RMSE of this test:0.4426465333 and Linear_size1 = 7 and Linear_size2 = 20
# The 1087 times of test: The RMSE of this test:0.4776973128 and Linear_size1 = 7 and Linear_size2 = 19
# The 1088 times of test: The RMSE of this test:0.4336274266 and Linear_size1 = 7 and Linear_size2 = 18
# The 1089 times of test: The RMSE of this test:0.4294625223 and Linear_size1 = 7 and Linear_size2 = 17
# The 1090 times of test: The RMSE of this test:0.4752184451 and Linear_size1 = 7 and Linear_size2 = 16
# The 1091 times of test: The RMSE of this test:0.4562781751 and Linear_size1 = 7 and Linear_size2 = 15
# The 1092 times of test: The RMSE of this test:0.4289920628 and Linear_size1 = 7 and Linear_size2 = 14
# The 1093 times of test: The RMSE of this test:0.4296542704 and Linear_size1 = 7 and Linear_size2 = 13
# The 1094 times of test: The RMSE of this test:0.4344209135 and Linear_size1 = 7 and Linear_size2 = 12
# The 1095 times of test: The RMSE of this test:0.5605273247 and Linear_size1 = 6 and Linear_size2 = 20
# The 1096 times of test: The RMSE of this test:0.4701695442 and Linear_size1 = 6 and Linear_size2 = 19
# The 1097 times of test: The RMSE of this test:0.4610786140 and Linear_size1 = 6 and Linear_size2 = 18
# The 1098 times of test: The RMSE of this test:0.4104719758 and Linear_size1 = 6 and Linear_size2 = 17
# The 1099 times of test: The RMSE of this test:0.4556964636 and Linear_size1 = 6 and Linear_size2 = 16
# The 1100 times of test: The RMSE of this test:0.4205452800 and Linear_size1 = 6 and Linear_size2 = 15
# The 1101 times of test: The RMSE of this test:0.4645344615 and Linear_size1 = 6 and Linear_size2 = 14
# The 1102 times of test: The RMSE of this test:0.4069611728 and Linear_size1 = 6 and Linear_size2 = 13
# The 1103 times of test: The RMSE of this test:0.4183122516 and Linear_size1 = 6 and Linear_size2 = 12
# The 1104 times of test: The RMSE of this test:0.4437970519 and Linear_size1 = 10 and Linear_size2 = 20
# The 1105 times of test: The RMSE of this test:0.4792700708 and Linear_size1 = 10 and Linear_size2 = 19
# The 1106 times of test: The RMSE of this test:0.4969978034 and Linear_size1 = 10 and Linear_size2 = 18
# The 1107 times of test: The RMSE of this test:0.5284196138 and Linear_size1 = 10 and Linear_size2 = 17
# The 1108 times of test: The RMSE of this test:0.4874911606 and Linear_size1 = 10 and Linear_size2 = 16
# The 1109 times of test: The RMSE of this test:0.4660111666 and Linear_size1 = 10 and Linear_size2 = 15
# The 1110 times of test: The RMSE of this test:0.4250743091 and Linear_size1 = 10 and Linear_size2 = 14
# The 1111 times of test: The RMSE of this test:0.4958319366 and Linear_size1 = 10 and Linear_size2 = 13
# The 1112 times of test: The RMSE of this test:0.4254742861 and Linear_size1 = 10 and Linear_size2 = 12
# The 1113 times of test: The RMSE of this test:0.4531430900 and Linear_size1 = 9 and Linear_size2 = 20
# The 1114 times of test: The RMSE of this test:0.4823552370 and Linear_size1 = 9 and Linear_size2 = 19
# The 1115 times of test: The RMSE of this test:0.3919154406 and Linear_size1 = 9 and Linear_size2 = 18
# The 1116 times of test: The RMSE of this test:0.5057823658 and Linear_size1 = 9 and Linear_size2 = 17
# The 1117 times of test: The RMSE of this test:0.4364671409 and Linear_size1 = 9 and Linear_size2 = 16
# The 1118 times of test: The RMSE of this test:0.4088774920 and Linear_size1 = 9 and Linear_size2 = 15
# The 1119 times of test: The RMSE of this test:0.4736236334 and Linear_size1 = 9 and Linear_size2 = 14
# The 1120 times of test: The RMSE of this test:0.4588806629 and Linear_size1 = 9 and Linear_size2 = 13
# The 1121 times of test: The RMSE of this test:0.4311317503 and Linear_size1 = 9 and Linear_size2 = 12
# The 1122 times of test: The RMSE of this test:0.5226216912 and Linear_size1 = 8 and Linear_size2 = 20
# The 1123 times of test: The RMSE of this test:0.4235330522 and Linear_size1 = 8 and Linear_size2 = 19
# The 1124 times of test: The RMSE of this test:0.4579650760 and Linear_size1 = 8 and Linear_size2 = 18
# The 1125 times of test: The RMSE of this test:0.4908441603 and Linear_size1 = 8 and Linear_size2 = 17
# The 1126 times of test: The RMSE of this test:0.4492516816 and Linear_size1 = 8 and Linear_size2 = 16
# The 1127 times of test: The RMSE of this test:0.4635375142 and Linear_size1 = 8 and Linear_size2 = 15
# The 1128 times of test: The RMSE of this test:0.5608780980 and Linear_size1 = 8 and Linear_size2 = 14
# The 1129 times of test: The RMSE of this test:0.5156509280 and Linear_size1 = 8 and Linear_size2 = 13
# The 1130 times of test: The RMSE of this test:0.4785526693 and Linear_size1 = 8 and Linear_size2 = 12
# The 1131 times of test: The RMSE of this test:0.4734973907 and Linear_size1 = 7 and Linear_size2 = 20
# The 1132 times of test: The RMSE of this test:0.4367811680 and Linear_size1 = 7 and Linear_size2 = 19
# The 1133 times of test: The RMSE of this test:0.4387532473 and Linear_size1 = 7 and Linear_size2 = 18
# The 1134 times of test: The RMSE of this test:0.4017574191 and Linear_size1 = 7 and Linear_size2 = 17
# The 1135 times of test: The RMSE of this test:0.4515418112 and Linear_size1 = 7 and Linear_size2 = 16
# The 1136 times of test: The RMSE of this test:0.4172840714 and Linear_size1 = 7 and Linear_size2 = 15
# The 1137 times of test: The RMSE of this test:0.3820282817 and Linear_size1 = 7 and Linear_size2 = 14
# The 1138 times of test: The RMSE of this test:0.4244664609 and Linear_size1 = 7 and Linear_size2 = 13
# The 1139 times of test: The RMSE of this test:0.4236550033 and Linear_size1 = 7 and Linear_size2 = 12
# The 1140 times of test: The RMSE of this test:0.4541974962 and Linear_size1 = 6 and Linear_size2 = 20
# The 1141 times of test: The RMSE of this test:0.3935391605 and Linear_size1 = 6 and Linear_size2 = 19
# The 1142 times of test: The RMSE of this test:0.4561739266 and Linear_size1 = 6 and Linear_size2 = 18
# The 1143 times of test: The RMSE of this test:0.4575312734 and Linear_size1 = 6 and Linear_size2 = 17
# The 1144 times of test: The RMSE of this test:0.5124719143 and Linear_size1 = 6 and Linear_size2 = 16
# The 1145 times of test: The RMSE of this test:0.4758154750 and Linear_size1 = 6 and Linear_size2 = 15
# The 1146 times of test: The RMSE of this test:0.4887440205 and Linear_size1 = 6 and Linear_size2 = 14
# The 1147 times of test: The RMSE of this test:0.4382493794 and Linear_size1 = 6 and Linear_size2 = 13
# The 1148 times of test: The RMSE of this test:0.4669889510 and Linear_size1 = 6 and Linear_size2 = 12
# The 1149 times of test: The RMSE of this test:0.4010007977 and Linear_size1 = 10 and Linear_size2 = 20
# The 1150 times of test: The RMSE of this test:0.4065192044 and Linear_size1 = 10 and Linear_size2 = 19
# The 1151 times of test: The RMSE of this test:0.5179053545 and Linear_size1 = 10 and Linear_size2 = 18
# The 1152 times of test: The RMSE of this test:0.4527610242 and Linear_size1 = 10 and Linear_size2 = 17
# The 1153 times of test: The RMSE of this test:0.5327758193 and Linear_size1 = 10 and Linear_size2 = 16
# The 1154 times of test: The RMSE of this test:0.4471104741 and Linear_size1 = 10 and Linear_size2 = 15
# The 1155 times of test: The RMSE of this test:0.4462475777 and Linear_size1 = 10 and Linear_size2 = 14
# The 1156 times of test: The RMSE of this test:0.4093937874 and Linear_size1 = 10 and Linear_size2 = 13
# The 1157 times of test: The RMSE of this test:0.4721315801 and Linear_size1 = 10 and Linear_size2 = 12
# The 1158 times of test: The RMSE of this test:0.4129251242 and Linear_size1 = 9 and Linear_size2 = 20
# The 1159 times of test: The RMSE of this test:0.4849926233 and Linear_size1 = 9 and Linear_size2 = 19
# The 1160 times of test: The RMSE of this test:0.4341309965 and Linear_size1 = 9 and Linear_size2 = 18
# The 1161 times of test: The RMSE of this test:0.4072813988 and Linear_size1 = 9 and Linear_size2 = 17
# The 1162 times of test: The RMSE of this test:0.3956053853 and Linear_size1 = 9 and Linear_size2 = 16
# The 1163 times of test: The RMSE of this test:0.4879149795 and Linear_size1 = 9 and Linear_size2 = 15
# The 1164 times of test: The RMSE of this test:0.4557018578 and Linear_size1 = 9 and Linear_size2 = 14
# The 1165 times of test: The RMSE of this test:0.4507229626 and Linear_size1 = 9 and Linear_size2 = 13
# The 1166 times of test: The RMSE of this test:0.5397617221 and Linear_size1 = 9 and Linear_size2 = 12
# The 1167 times of test: The RMSE of this test:0.5098304749 and Linear_size1 = 8 and Linear_size2 = 20
# The 1168 times of test: The RMSE of this test:0.3864263594 and Linear_size1 = 8 and Linear_size2 = 19
# The 1169 times of test: The RMSE of this test:0.4565034807 and Linear_size1 = 8 and Linear_size2 = 18
# The 1170 times of test: The RMSE of this test:0.4073789716 and Linear_size1 = 8 and Linear_size2 = 17
# The 1171 times of test: The RMSE of this test:0.4432881773 and Linear_size1 = 8 and Linear_size2 = 16
# The 1172 times of test: The RMSE of this test:0.4411462843 and Linear_size1 = 8 and Linear_size2 = 15
# The 1173 times of test: The RMSE of this test:0.5473591685 and Linear_size1 = 8 and Linear_size2 = 14
# The 1174 times of test: The RMSE of this test:0.4416116476 and Linear_size1 = 8 and Linear_size2 = 13
# The 1175 times of test: The RMSE of this test:0.4488059878 and Linear_size1 = 8 and Linear_size2 = 12
# The 1176 times of test: The RMSE of this test:0.4524965882 and Linear_size1 = 7 and Linear_size2 = 20
# The 1177 times of test: The RMSE of this test:0.4762416482 and Linear_size1 = 7 and Linear_size2 = 19
# The 1178 times of test: The RMSE of this test:0.4697672427 and Linear_size1 = 7 and Linear_size2 = 18
# The 1179 times of test: The RMSE of this test:0.4209858179 and Linear_size1 = 7 and Linear_size2 = 17
# The 1180 times of test: The RMSE of this test:0.4580448568 and Linear_size1 = 7 and Linear_size2 = 16
# The 1181 times of test: The RMSE of this test:0.3883539438 and Linear_size1 = 7 and Linear_size2 = 15
# The 1182 times of test: The RMSE of this test:0.4164440334 and Linear_size1 = 7 and Linear_size2 = 14
# The 1183 times of test: The RMSE of this test:0.4694621265 and Linear_size1 = 7 and Linear_size2 = 13
# The 1184 times of test: The RMSE of this test:0.4465925694 and Linear_size1 = 7 and Linear_size2 = 12
# The 1185 times of test: The RMSE of this test:0.5417493582 and Linear_size1 = 6 and Linear_size2 = 20
# The 1186 times of test: The RMSE of this test:0.4257873297 and Linear_size1 = 6 and Linear_size2 = 19
# The 1187 times of test: The RMSE of this test:0.4122816622 and Linear_size1 = 6 and Linear_size2 = 18
# The 1188 times of test: The RMSE of this test:0.4476813972 and Linear_size1 = 6 and Linear_size2 = 17
# The 1189 times of test: The RMSE of this test:0.6234163642 and Linear_size1 = 6 and Linear_size2 = 16
# The 1190 times of test: The RMSE of this test:0.4138810933 and Linear_size1 = 6 and Linear_size2 = 15
# The 1191 times of test: The RMSE of this test:0.4221082330 and Linear_size1 = 6 and Linear_size2 = 14
# The 1192 times of test: The RMSE of this test:0.4615719914 and Linear_size1 = 6 and Linear_size2 = 13
# The 1193 times of test: The RMSE of this test:0.4793581367 and Linear_size1 = 6 and Linear_size2 = 12
# The 1194 times of test: The RMSE of this test:0.4551517665 and Linear_size1 = 10 and Linear_size2 = 20
# The 1195 times of test: The RMSE of this test:0.4723846912 and Linear_size1 = 10 and Linear_size2 = 19
# The 1196 times of test: The RMSE of this test:0.4864679575 and Linear_size1 = 10 and Linear_size2 = 18
# The 1197 times of test: The RMSE of this test:0.4311847687 and Linear_size1 = 10 and Linear_size2 = 17
# The 1198 times of test: The RMSE of this test:0.4645729959 and Linear_size1 = 10 and Linear_size2 = 16
# The 1199 times of test: The RMSE of this test:0.4407052398 and Linear_size1 = 10 and Linear_size2 = 15
# The 1200 times of test: The RMSE of this test:0.3947622776 and Linear_size1 = 10 and Linear_size2 = 14
# The 1201 times of test: The RMSE of this test:0.4828400612 and Linear_size1 = 10 and Linear_size2 = 13
# The 1202 times of test: The RMSE of this test:0.4565862417 and Linear_size1 = 10 and Linear_size2 = 12
# The 1203 times of test: The RMSE of this test:0.4354947805 and Linear_size1 = 9 and Linear_size2 = 20
# The 1204 times of test: The RMSE of this test:0.6934989691 and Linear_size1 = 9 and Linear_size2 = 19
# The 1205 times of test: The RMSE of this test:0.4652363062 and Linear_size1 = 9 and Linear_size2 = 18
# The 1206 times of test: The RMSE of this test:0.4469588399 and Linear_size1 = 9 and Linear_size2 = 17
# The 1207 times of test: The RMSE of this test:0.4536130726 and Linear_size1 = 9 and Linear_size2 = 16
# The 1208 times of test: The RMSE of this test:0.4652308822 and Linear_size1 = 9 and Linear_size2 = 15
# The 1209 times of test: The RMSE of this test:0.4321593344 and Linear_size1 = 9 and Linear_size2 = 14
# The 1210 times of test: The RMSE of this test:0.3979721963 and Linear_size1 = 9 and Linear_size2 = 13
# The 1211 times of test: The RMSE of this test:0.4541782141 and Linear_size1 = 9 and Linear_size2 = 12
# The 1212 times of test: The RMSE of this test:0.4557116628 and Linear_size1 = 8 and Linear_size2 = 20
# The 1213 times of test: The RMSE of this test:0.4281644225 and Linear_size1 = 8 and Linear_size2 = 19
# The 1214 times of test: The RMSE of this test:0.4475640357 and Linear_size1 = 8 and Linear_size2 = 18
# The 1215 times of test: The RMSE of this test:0.4330382943 and Linear_size1 = 8 and Linear_size2 = 17
# The 1216 times of test: The RMSE of this test:0.4354081750 and Linear_size1 = 8 and Linear_size2 = 16
# The 1217 times of test: The RMSE of this test:0.4768369794 and Linear_size1 = 8 and Linear_size2 = 15
# The 1218 times of test: The RMSE of this test:0.4415010214 and Linear_size1 = 8 and Linear_size2 = 14
# The 1219 times of test: The RMSE of this test:0.4562035799 and Linear_size1 = 8 and Linear_size2 = 13
# The 1220 times of test: The RMSE of this test:0.4128002226 and Linear_size1 = 8 and Linear_size2 = 12
# The 1221 times of test: The RMSE of this test:0.4376259744 and Linear_size1 = 7 and Linear_size2 = 20
# The 1222 times of test: The RMSE of this test:0.4324568808 and Linear_size1 = 7 and Linear_size2 = 19
# The 1223 times of test: The RMSE of this test:0.4563622773 and Linear_size1 = 7 and Linear_size2 = 18
# The 1224 times of test: The RMSE of this test:0.4342296422 and Linear_size1 = 7 and Linear_size2 = 17
# The 1225 times of test: The RMSE of this test:0.5075714588 and Linear_size1 = 7 and Linear_size2 = 16
